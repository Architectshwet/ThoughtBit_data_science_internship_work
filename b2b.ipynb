# %%
import pandas as pd

# %%
# Load spreadsheet: xl
xl = pd.ExcelFile('sales.xlsx')

# Print sheet names
print(xl.sheet_names)
# Out:
# ['B2B - 4A, 4B, 4C, 6B, 6C', 'B2CL - 5A, 5B', 'B2CS - 7', 'CDNR - 9B', 'CDNUR - 9B', 'EXP - 6A', 'AT - 11A(1), 11A(2)', 'ATADJ - 11B(1), 11B(2)', 'EXEMP - 8A, 8B, 8C, 8D', 'HSN - 12', 'DOC - 13', 'POS List', 'Master']

# %%
# Load a sheet into a DataFrame by name: df1
df1 = xl.parse('B2B - 4A, 4B, 4C, 6B, 6C')

# Print the head of the DataFrame df1
df1.head()
# Out:
#   Invoice Type* Receiver GSTIN/UIN* Invoice No.* Invoice Date*  \
# 0       Regular     12GEOPS0823BBZH         1000    2017-07-14
# 1       Regular     12GEOPS0823BBZH        A1001    2017-07-14
# 2       Regular     12GEOPS0823BBZH        1000A    2017-07-14
# 3       Regular     12GEOPS0823BBZH       A/1001    2017-07-14
# 4       Regular     12GEOPS0823BBZH       A/1002    2017-07-14
#
#    Invoice Value (₹)*   Place of Supply* Supply Type* Reverse Charge*  \
# 0               50000  37-Andhra Pradesh        Inter               N
# 1               43000  37-Andhra Pradesh        Inter               N
# 2               42000       36-Telangana        Inter               N
# 3               55000     05-Uttarakhand        Inter               Y
# 4               40330     05-Uttarakhand        Inter               Y
#
#   E-Commerce GSTIN  Rate*  Taxable Value (₹)*  Integrated Tax (₹)*  \
# 0              NaN  12.00               45000               5400.0
# ...

# %%
df1.columns
# Out:
# Index(['Invoice Type*', 'Receiver GSTIN/UIN*', 'Invoice No.*', 'Invoice Date*',
#        'Invoice Value (₹)*', 'Place of Supply*', 'Supply Type*',
#        'Reverse Charge*', 'E-Commerce GSTIN', 'Rate*', 'Taxable Value (₹)*',
#        'Integrated Tax (₹)*', 'Central Tax (₹)*', 'State/UT Tax (₹)*',
#        'Cess (₹)'],
#       dtype='object')

# %%
df1.columns = ['Invoice_Type', 'Receiver_GSTIN/UIN', 'Invoice_No', 'Invoice_Date',
       'Invoice_Value', 'Place_of_Supply', 'Supply_Type',
       'Reverse Charge', 'E-Commerce_GSTIN', 'Rate', 'Taxable_Value',
       'Integrated_Tax', 'Central_Tax', 'State/UT_Tax',
       'Cess (₹)']

# %%
df1.columns
# Out:
# Index(['Invoice_Type', 'Receiver_GSTIN/UIN', 'Invoice_No', 'Invoice_Date',
#        'Invoice_Value', 'Place_of_Supply', 'Supply_Type', 'Reverse Charge',
#        'E-Commerce_GSTIN', 'Rate', 'Taxable_Value', 'Integrated_Tax',
#        'Central_Tax', 'State/UT_Tax', 'Cess (₹)'],
#       dtype='object')

# %%
df1.head()
# Out:
#   Invoice_Type Receiver_GSTIN/UIN Invoice_No Invoice_Date  Invoice_Value  \
# 0      Regular    12GEOPS0823BBZH       1000   2017-07-14          50000
# 1      Regular    12GEOPS0823BBZH      A1001   2017-07-14          43000
# 2      Regular    12GEOPS0823BBZH      1000A   2017-07-14          42000
# 3      Regular    12GEOPS0823BBZH     A/1001   2017-07-14          55000
# 4      Regular    12GEOPS0823BBZH     A/1002   2017-07-14          40330
#
#      Place_of_Supply Supply_Type Reverse Charge E-Commerce_GSTIN   Rate  \
# 0  37-Andhra Pradesh       Inter              N              NaN  12.00
# 1  37-Andhra Pradesh       Inter              N              NaN   5.00
# 2       36-Telangana       Inter              N              NaN  12.00
# 3     05-Uttarakhand       Inter              Y              NaN  28.00
# 4     05-Uttarakhand       Inter              Y              NaN   0.25
#
#    Taxable_Value  Integrated_Tax  Central_Tax  State/UT_Tax  Cess (₹)
# ...

# %%
df1['Receiver_GSTIN/UIN'].value_counts()
# Out:
# 12GEOPS0823BBZH    13
# 33GEOPS0823BBZH     1
# Name: Receiver_GSTIN/UIN, dtype: int64

# %%
df1['Invoice_Type'].value_counts()
# Out:
# Regular    14
# Name: Invoice_Type, dtype: int64

# %%
df1['Integrated_Tax'].value_counts()
# Out:
# 4800.0     3
# 1200.0     2
# 11200.0    1
# 0.0        1
# 4500.0     1
# 1750.0     1
# 100.0      1
# 14000.0    1
# 2000.0     1
# 5400.0     1
# Name: Integrated_Tax, dtype: int64

# %%
df1.describe()
# Out:
#        Invoice_Value       Rate  Taxable_Value  Integrated_Tax  Central_Tax  \
# count      14.000000  14.000000      14.000000       13.000000          1.0
# mean    42809.285714  12.517857   36071.428571     4288.461538       2800.0
# std      9391.566155   9.850061   10593.643128     4191.666029          NaN
# min     20000.000000   0.000000   10000.000000        0.000000       2800.0
# 25%     42250.000000   5.000000   36250.000000     1200.000000       2800.0
# 50%     43500.000000  12.000000   40000.000000     4500.000000       2800.0
# 75%     49500.000000  16.500000   40000.000000     4800.000000       2800.0
# max     55000.000000  28.000000   50000.000000    14000.000000       2800.0
#
#        State/UT_Tax     Cess (₹)
# count           1.0     5.000000
# mean         2800.0  3591.200000
# std             NaN  2794.098638
# min          2800.0   500.000000
# 25%          2800.0   756.000000
# 50%          2800.0  5000.000000
# 75%          2800.0  5000.000000
# ...

# %%
df1.dtypes
# Out:
# Invoice_Type                  object
# Receiver_GSTIN/UIN            object
# Invoice_No                    object
# Invoice_Date          datetime64[ns]
# Invoice_Value                  int64
# Place_of_Supply               object
# Supply_Type                   object
# Reverse Charge                object
# E-Commerce_GSTIN              object
# Rate                         float64
# Taxable_Value                  int64
# Integrated_Tax               float64
# Central_Tax                  float64
# State/UT_Tax                 float64
# Cess (₹)                     float64
# dtype: object

# %%
df1.isnull().any()
# Out:
# Invoice_Type          False
# Receiver_GSTIN/UIN    False
# Invoice_No            False
# Invoice_Date          False
# Invoice_Value         False
# Place_of_Supply       False
# Supply_Type           False
# Reverse Charge        False
# E-Commerce_GSTIN       True
# Rate                  False
# Taxable_Value         False
# Integrated_Tax         True
# Central_Tax            True
# State/UT_Tax           True
# Cess (₹)               True
# dtype: bool

# %%
df1.shape
# Out:
# (14, 15)

# %% [markdown]
# # Visualizations

# %% [markdown]
# 1. Distplot of all the features individually with it's kde too.

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import matplotlib as matplot
# %matplotlib inline

# %%
# Set up the matplotlib figure
f, axes = plt.subplots(ncols=3, figsize=(15, 6))

sns.distplot(df1.Invoice_Value, 
             kde=False,
             color="g",
             ax=axes[0]).set_title('Invoice_Value Distribution')
axes[0].set_ylabel('Invoice_Value Count')


sns.distplot(df1.Rate, 
             kde=False, 
             color="r", 
             ax=axes[1]).set_title('Rate Distribution')
axes[1].set_ylabel('Rate Count')


sns.distplot(df1.Taxable_Value, 
             kde=False, 
             color="b", 
             ax=axes[2]).set_title('Taxable_Value Distribution')
axes[2].set_ylabel('Taxable_Value Count')

# %%
# Set up the matplotlib figure
f, axes = plt.subplots(ncols=3, figsize=(15, 6))

sns.distplot(df1.Invoice_Value, 
             kde=True, color="g", 
             ax=axes[0]).set_title('Invoice_Value Distribution')
axes[0].set_ylabel('Invoice_Value Count')


sns.distplot(df1.Rate,
             kde=True,
             color="r",
             ax=axes[1]).set_title('Rate Distribution')
axes[1].set_ylabel('Rate Count')


sns.distplot(df1.Taxable_Value,
             kde=True,
             color="b",
             ax=axes[2]).set_title('Taxable_Value Distribution')
axes[2].set_ylabel('Taxable_Value Count')

# %% [markdown]
# For the features "Centrai_Tax", "State/UT_Tax", "Cess (₹)", some values were empty, I just filled with some value like mean of that column

# %%
df1.Central_Tax.fillna(0, inplace=True)
df1.loc[df1["Central_Tax"] == 0, "Central_Tax"] = df1.Central_Tax.mean()

df1['State/UT_Tax'].fillna(0, inplace=True)
df1.loc[df1["State/UT_Tax"] == 0, "State/UT_Tax"] = df1['State/UT_Tax'].mean()

df1["Cess (₹)"].fillna(0, inplace=True)
df1.loc[df1["Cess (₹)"] == 0, "Cess (₹)"] = df1["Cess (₹)"].mean()

# %%
df1["Integrated_Tax"].fillna(0, inplace=True)
df1.loc[df1["Integrated_Tax"] == 0, "Integrated_Tax"] = df1["Integrated_Tax"].mean()

# %%
# Set up the matplotlib figure
f, axes = plt.subplots( ncols=3, figsize=(15, 6))


sns.distplot(df1.Central_Tax, 
             kde=False,
             color="g",
             ax=axes[0]).set_title('Central_Tax Distribution')
axes[0].set_ylabel('Central_Tax Count')


sns.distplot(df1['State/UT_Tax'],
             kde=False,
             color="r",
             ax=axes[1]).set_title('State/UT_Tax Distribution')
axes[1].set_ylabel('State/UT_Tax Count')


sns.distplot(df1['Cess (₹)'],
             kde=False,
             color="b",
             ax=axes[2]).set_title('Cess (₹) Distribution')
axes[2].set_ylabel('Cess (₹) Count')

# %%
# Set up the matplotlib figure
f, axes = plt.subplots( ncols=3, figsize=(15, 6))


sns.distplot(df1.Central_Tax,
             kde=True,
             color="g",
             ax=axes[0]).set_title('Central_Tax Distribution')
axes[0].set_ylabel('Central_Tax Count')


sns.distplot(df1['State/UT_Tax'],
             kde=True,
             color="r",
             ax=axes[1]).set_title('State/UT_Tax Distribution')
axes[1].set_ylabel('State/UT_Tax Count')


sns.distplot(df1['Cess (₹)'],
             kde=True,
             color="b",
             ax=axes[2]).set_title('Cess (₹) Distribution')
axes[2].set_ylabel('Cess (₹) Count')

# %%
sns.distplot(df1['Integrated_Tax'],
             kde=False,
             color="b").set_title('Integrated_Tax Distribution')

# %%
sns.distplot(df1['Integrated_Tax'],
             kde=True,
             color="b").set_title('Integrated_Tax Distribution')

# %% [markdown]
# 2) countplot of all the features

# %%
f, ax = plt.subplots(figsize=(12, 8))
sns.countplot(x="Invoice_Value",
              data=df1).set_title('Invoice_Value Distribution');

# %%
# Set up the matplotlib figure
f, axes = plt.subplots( ncols=3, figsize=(15, 6))

sns.countplot(df1.Rate,
              color="g",
              ax=axes[0]).set_title('Rate Distribution')
axes[0].set_ylabel('Rate Count')


sns.countplot(df1['Taxable_Value'],
              color="r",
              ax=axes[1]).set_title('Taxable_Value Distribution')
axes[1].set_ylabel('Taxable_Value Count')


sns.countplot(df1['Integrated_Tax'],
              color="b",
              ax=axes[2]).set_title('Integrated_Tax Distribution')
axes[2].set_ylabel('Integrated_Tax Count')

# %%
# Set up the matplotlib figure
f, axes = plt.subplots( ncols=3, figsize=(15, 6))

sns.countplot(df1.Central_Tax,
              color="g",
              ax=axes[0]).set_title('Central_Tax Distribution')
axes[0].set_ylabel('Central_Tax Count')


sns.countplot(df1['State/UT_Tax'],
              color="r",
              ax=axes[1]).set_title('State/UT_Tax Distribution')
axes[1].set_ylabel('State/UT_Tax Count')


sns.countplot(df1['Cess (₹)'],
              color="b",
              ax=axes[2]).set_title('Cess (₹) Distribution')
axes[2].set_ylabel('Cess (₹) Count')

# %%
# Types of colors
color_types = ['#78C850','#F08030','#6890F0','#A8B820','#A8A878','#A040A0','#F8D030',  
                '#E0C068','#EE99AC','#C03028','#F85888','#B8A038','#705898','#98D8D8','#7038F8']

# Count Plot (a.k.a. Bar Plot)
sns.countplot(x='Place_of_Supply', 
              data=df1,
              palette=color_types).set_title('Place_of_Supply Distribution');

# %%
# Types of colors
color_types = ['#78C850','#F08030','#6890F0','#A8B820','#A8A878','#A040A0','#F8D030',  
                '#E0C068','#EE99AC','#C03028','#F85888','#B8A038','#705898','#98D8D8','#7038F8']

# Count Plot (a.k.a. Bar Plot)
sns.countplot(x='Supply_Type',
              data=df1,
              palette=color_types).set_title('Supply_Type Distribution');

# %% [markdown]
# 3) countplot to interpret results between two categorical variables

# %%
f, ax = plt.subplots(figsize=(12, 8))
sns.countplot(x="Receiver_GSTIN/UIN",
              hue='Place_of_Supply',
              data=df1).set_title('Receiver_GSTIN/UIN-Place_of_Supply Distribution');

# %%
f, ax = plt.subplots(figsize=(12, 8))
sns.countplot(x="Supply_Type",
              hue='Place_of_Supply',
              data=df1).set_title('Supply_Type-Place_of_Supply Distribution');

# %%
sns.factorplot("Supply_Type",
               col="Place_of_Supply",
               col_wrap=4,
               data=df1,
               kind="count",
               size=6,
               aspect=.9)

# %% [markdown]
# 4) factorplot of all the numerical variable with respect to "Place_of_supply" and "supply_type"

# %%
sns.factorplot(x="Supply_Type",
               y="Invoice_Value",
               hue='Place_of_Supply',
               data=df1,
               size =6);

# %%
sns.factorplot(x="Supply_Type",
               y="Rate",
               hue='Place_of_Supply',
               data=df1,
               size = 6);

# %%
sns.factorplot(x="Supply_Type",
               y="Taxable_Value",
               hue='Place_of_Supply',
               data=df1,
               size = 6);

# %%
sns.factorplot(x="Supply_Type",
               y="Integrated_Tax",
               hue='Place_of_Supply',
               data=df1,
               size = 6);

# %%
sns.factorplot(x="Supply_Type",
               y="Central_Tax",
               hue='Place_of_Supply',
               data=df1,
               size = 6);

# %%
sns.factorplot(x="Supply_Type",
               y="State/UT_Tax",
               hue='Place_of_Supply',
               data=df1,
               size = 6);

# %%
sns.factorplot(x="Supply_Type",
               y="Cess (₹)",
               hue='Place_of_Supply',
               data=df1,
               size = 6);

# %% [markdown]
# 5) factorplot of all the continous variable with respect to just "place_of_supply"

# %%
sns.factorplot(x="Place_of_Supply",
               y="Invoice_Value",
               data=df1,
               size = 6);

# %%
sns.factorplot(x="Place_of_Supply",
               y="Rate",
               data=df1,
               size = 6);

# %%
sns.factorplot(x="Place_of_Supply",
               y="Taxable_Value",
               data=df1,
               size = 6);

# %%
sns.factorplot(x="Place_of_Supply",
               y="Integrated_Tax",
               data=df1,
               size = 6);

# %%
sns.factorplot(x="Place_of_Supply",
               y="Central_Tax",
               data=df1,
               size = 6);

# %%
sns.factorplot(x="Place_of_Supply",
               y="State/UT_Tax",
               data=df1,
               size = 6);

# %%
sns.factorplot(x="Place_of_Supply",
               y="Cess (₹)",
               data=df1,
               size = 6);

# %% [markdown]
# 6) kdeplot of all the continous variable with respect to "place_of_supply"

# %%
# Kernel Density Plot
fig = plt.figure(figsize=(15,4),)

ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '37-Andhra Pradesh'),'Rate'],
               color='b',
               shade=True,
               label='Andhra Pradesh')
ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '05-Uttarakhand'),'Rate'],
               color='r',
               shade=True,
               label='tUttarakhand')
ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '36-Telangana'),'Rate'],
               color='g',
               shade=True,
               label='Telangana')
ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '33-Tamil Nadu'),'Rate'],
               color='y',
               shade=True,
               label='Tamil Nadu')

ax.set(xlabel='Rate', 
       ylabel='Frequency')
plt.title('Rate Distribution - Place of supply')
# Out:
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\numpy\core\_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\numpy\core\_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py:22: RuntimeWarning: invalid value encountered in minimum
#   return np.minimum(np.std(X, axis=0, ddof=1), IQR)

# %%
# Kernel Density Plot
fig = plt.figure(figsize=(15,4),)

ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '37-Andhra Pradesh'),'Taxable_Value'] ,
               color='b',
               shade=True,
               label='Andhra Pradesh')
ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '05-Uttarakhand'),'Taxable_Value'],
               color='r',
               shade=True,
               label='tUttarakhand')
ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '36-Telangana'),'Taxable_Value'] ,
               color='g',
               shade=True,
               label='Telangana')
ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '33-Tamil Nadu'),'Taxable_Value'],
               color='y',
               shade=True,
               label='Tamil Nadu')

ax.set(xlabel='Taxable_Value',
       ylabel='Frequency')
plt.title('Taxable_Value - Place of supply')
# Out:
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:494: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X,a,b,gridsize)/(delta*nobs)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\numpy\core\_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\numpy\core\_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py:22: RuntimeWarning: invalid value encountered in minimum
#   return np.minimum(np.std(X, axis=0, ddof=1), IQR)

# %%
# Kernel Density Plot
fig = plt.figure(figsize=(15,4),)

ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '37-Andhra Pradesh'),'Integrated_Tax'],
               color='b',
               shade=True,
               label='Andhra Pradesh')
ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '05-Uttarakhand'),'Integrated_Tax'],
               color='r',
               shade=True,
               label='tUttarakhand')
ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '36-Telangana'),'Integrated_Tax'] ,
               color='g',
               shade=True,
               label='Telangana')
ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '33-Tamil Nadu'),'Integrated_Tax'],
               color='y',
               shade=True,
               label='Tamil Nadu')

ax.set(xlabel='Integrated_Tax',
       ylabel='Frequency')
plt.title('Integrated_Tax - Place of supply')
# Out:
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\numpy\core\_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\numpy\core\_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py:22: RuntimeWarning: invalid value encountered in minimum
#   return np.minimum(np.std(X, axis=0, ddof=1), IQR)

# %%
# Kernel Density Plot
fig = plt.figure(figsize=(15,4),)

ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '37-Andhra Pradesh'),'Invoice_Value'],
               color='b',
               shade=True,
               label='Andhra Pradesh')
ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '05-Uttarakhand'),'Invoice_Value'] , 
               color='r',shade=True, label='tUttarakhand')
ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '36-Telangana'),'Invoice_Value'] ,
               color='g',shade=True,label='Telangana')
ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '33-Tamil Nadu'),'Invoice_Value'] ,
               color='y',shade=True, label='Tamil Nadu')

ax.set(xlabel='Invoice_Value', ylabel='Frequency')
plt.title('Invoice_Value - Place of supply')
# Out:
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\numpy\core\_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\numpy\core\_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py:22: RuntimeWarning: invalid value encountered in minimum
#   return np.minimum(np.std(X, axis=0, ddof=1), IQR)

# %%
# Kernel Density Plot
fig = plt.figure(figsize=(15,4),)

ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '37-Andhra Pradesh'),'Cess (₹)'] ,
               color='b',shade=True,label='Andhra Pradesh')
ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '05-Uttarakhand'),'Cess (₹)'] , color='r',shade=True, label='tUttarakhand')
ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '36-Telangana'),'Cess (₹)'] , color='g',shade=True,label='Telangana')
ax=sns.kdeplot(df1.loc[(df1['Place_of_Supply'] == '33-Tamil Nadu'),'Cess (₹)'] , color='y',shade=True, label='Tamil Nadu')

ax.set(xlabel='Cess (₹)', ylabel='Frequency')
plt.title('Cess (₹) - Place of supply')
# Out:
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:494: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X,a,b,gridsize)/(delta*nobs)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\numpy\core\_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\numpy\core\_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py:22: RuntimeWarning: invalid value encountered in minimum
#   return np.minimum(np.std(X, axis=0, ddof=1), IQR)

# %%
fig = plt.figure(figsize=(15,4),)
# Let's look at the density of the age of happy/unhappy customers for saldo_var30
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(sns.kdeplot, "Invoice_Value", shade = True) \
   .add_legend();

# %% [markdown]
# 7) boxplot of all the continous variable with "place_of_supply"

# %%
ax = sns.boxplot(x="Place_of_Supply", y="Invoice_Value", 
                data=df1)
ax = sns.stripplot(x="Place_of_Supply", y="Invoice_Value",
                   data=df1, jitter=True,
                   edgecolor="gray")
sns.plt.title("Place_of_Supply by Invoice_Value",fontsize=12);

# %%
ax = sns.boxplot(x="Place_of_Supply", y="Rate", 
                data=df1)
ax = sns.stripplot(x="Place_of_Supply", y="Rate",
                   data=df1, jitter=True,
                   edgecolor="gray")
sns.plt.title("Place_of_Supply by Rate",fontsize=12);

# %%
ax = sns.boxplot(x="Place_of_Supply", y="Taxable_Value", 
                data=df1)
ax = sns.stripplot(x="Place_of_Supply", y="Taxable_Value",
                   data=df1, jitter=True,
                   edgecolor="gray")
sns.plt.title("Place_of_Supply by Taxable_Value",fontsize=12);

# %%
ax = sns.boxplot(x="Place_of_Supply", y="Integrated_Tax", 
                data=df1)
ax = sns.stripplot(x="Place_of_Supply", y="Integrated_Tax",
                   data=df1, jitter=True,
                   edgecolor="gray")
sns.plt.title("Place_of_Supply by Integrated_Tax",fontsize=12);

# %%
ax = sns.boxplot(x="Place_of_Supply", y="Central_Tax", 
                data=df1)
ax = sns.stripplot(x="Place_of_Supply", y="Central_Tax",
                   data=df1, jitter=True,
                   edgecolor="gray")
sns.plt.title("Place_of_Supply by Central_Tax",fontsize=12);

# %%
ax = sns.boxplot(x="Place_of_Supply", y="State/UT_Tax", 
                data=df1)
ax = sns.stripplot(x="Place_of_Supply", y="State/UT_Tax",
                   data=df1, jitter=True,
                   edgecolor="gray")
sns.plt.title("Place_of_Supply by State/UT_Tax",fontsize=12);

# %%
ax = sns.boxplot(x="Place_of_Supply", y="Cess (₹)", 
                data=df1)
ax = sns.stripplot(x="Place_of_Supply", y="Cess (₹)",
                   data=df1, jitter=True,
                   edgecolor="gray")
sns.plt.title("Place_of_Supply by Cess (₹)",fontsize=12);

# %% [markdown]
# 8) Scatter plot between two continous variables with respect to "place_of_supply"

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "Invoice_Value", "Rate") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "Taxable_Value", "Rate") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "Integrated_Tax", "Rate") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "Central_Tax", "Rate") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "State/UT_Tax", "Rate") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "Cess (₹)", "Rate") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "Taxable_Value", "Invoice_Value") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "Integrated_Tax", "Invoice_Value") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "Central_Tax", "Invoice_Value") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "State/UT_Tax", "Invoice_Value") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "Cess (₹)", "Invoice_Value") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "Integrated_Tax", "Taxable_Value") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "Central_Tax", "Taxable_Value") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "State/UT_Tax", "Taxable_Value") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "Cess (₹)", "Taxable_Value") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "Central_Tax", "Integrated_Tax") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "State/UT_Tax", "Integrated_Tax") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "Cess (₹)", "Integrated_Tax") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "State/UT_Tax", "Central_Tax") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "Cess (₹)", "Central_Tax") \
   .add_legend();

# %%
sns.FacetGrid(df1, hue="Place_of_Supply", size=8) \
   .map(plt.scatter, "Cess (₹)", "State/UT_Tax") \
   .add_legend();

# %%
fig = plt.figure(figsize=(15,8),)

g = sns.FacetGrid(df1, hue="Place_of_Supply", margin_titles=True)
g=g.map(plt.scatter, "Rate", "Taxable_Value",edgecolor="w").add_legend();

# %% [markdown]
# 9) just a scatter plot between all the continous variable

# %%
g = sns.jointplot("Rate", "Invoice_Value", data=df1)

# %%
g = sns.jointplot("Taxable_Value", "Invoice_Value", data=df1)

# %%
g = sns.jointplot("Integrated_Tax", "Invoice_Value", data=df1)

# %%
g = sns.jointplot("Central_Tax", "Invoice_Value", data=df1)

# %%
g = sns.jointplot("State/UT_Tax", "Invoice_Value", data=df1)

# %%
g = sns.jointplot("Cess (₹)", "Invoice_Value", data=df1)

# %%
g = sns.jointplot("Taxable_Value", "Rate", data=df1)

# %%
g = sns.jointplot("Integrated_Tax", "Rate", data=df1)

# %%
g = sns.jointplot("Central_Tax", "Rate", data=df1)

# %%
g = sns.jointplot("State/UT_Tax", "Rate", data=df1)

# %%
g = sns.jointplot("Cess (₹)", "Rate", data=df1)

# %%
g = sns.jointplot("Integrated_Tax", "Taxable_Value", data=df1)

# %%
g = sns.jointplot("Central_Tax", "Taxable_Value", data=df1)

# %%
g = sns.jointplot("State/UT_Tax", "Taxable_Value", data=df1)

# %%
g = sns.jointplot("Central_Tax", "Integrated_Tax", data=df1)

# %%
g = sns.jointplot("State/UT_Tax", "Integrated_Tax", data=df1)

# %%
g = sns.jointplot("Cess (₹)", "Integrated_Tax", data=df1)

# %%
g = sns.jointplot("State/UT_Tax", "Central_Tax", data=df1)

# %%
g = sns.jointplot("Cess (₹)", "Central_Tax", data=df1)

# %%
g = sns.jointplot("Cess (₹)", "State/UT_Tax", data=df1)

# %% [markdown]
# 10) Just another way to understand relationship between variables in one go

# %%
sns.pairplot(df1[['Rate','Taxable_Value','Invoice_Value','Place_of_Supply']], hue="Place_of_Supply", size=2, diag_kind="kde");
# Out:
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\numpy\core\_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\numpy\core\_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py:22: RuntimeWarning: invalid value encountered in minimum
#   return np.minimum(np.std(X, axis=0, ddof=1), IQR)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:494: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X,a,b,gridsize)/(delta*nobs)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sns.pairplot(df1[['Integrated_Tax','Central_Tax','State/UT_Tax','Place_of_Supply']], hue="Place_of_Supply", size=2, diag_kind="kde");
# Out:
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\numpy\core\_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\numpy\core\_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py:22: RuntimeWarning: invalid value encountered in minimum
#   return np.minimum(np.std(X, axis=0, ddof=1), IQR)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:494: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X,a,b,gridsize)/(delta*nobs)
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# Some other ways to look at the data tried

# %%
from pandas.tools.plotting import radviz

# %%
# A final multivariate visualization technique pandas has is radviz
# Which puts each feature as a point on a 2D plane, and then simulates
# having each sample attached to those points through a spring weighted
# by the relative value for that feature
radviz(df1[['Rate','Invoice_Value','Taxable_Value','Place_of_Supply']], "Place_of_Supply");
# Out:
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.radviz' is deprecated, import 'pandas.plotting.radviz' instead.
#   """Entry point for launching an IPython kernel.

# %%
radviz(df1[['Integrated_Tax','Central_Tax','State/UT_Tax','Place_of_Supply']], "Place_of_Supply");
# Out:
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.radviz' is deprecated, import 'pandas.plotting.radviz' instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\Architect_shwet\Anaconda3\lib\site-packages\pandas\plotting\_misc.py:201: RuntimeWarning: invalid value encountered in true_divide
#   y = (s * row_).sum(axis=0) / row.sum()

# %% [markdown]
# 11) histograms of the variables with respect to "place_of_Supply"

# %%
sns.FacetGrid(df1, 
              hue="Place_of_Supply", 
              size=6) \
   .map(plt.hist, "Invoice_Value") \
   .add_legend();

# %%
sns.FacetGrid(df1, 
              hue="Place_of_Supply", 
              size=6) \
   .map(plt.hist, "Rate") \
   .add_legend();

# %%
sns.FacetGrid(df1, 
              hue="Place_of_Supply", 
              size=6) \
   .map(plt.hist, "Taxable_Value") \
   .add_legend();

# %%
sns.FacetGrid(df1, 
              hue="Place_of_Supply", 
              size=6) \
   .map(plt.hist, "Integrated_Tax") \
   .add_legend();

# %%
sns.FacetGrid(df1, 
              hue="Place_of_Supply", 
              size=6) \
   .map(plt.hist, "Central_Tax") \
   .add_legend();

# %%
sns.FacetGrid(df1, 
              hue="Place_of_Supply", 
              size=6) \
   .map(plt.hist, "State/UT_Tax") \
   .add_legend();

# %%
df1["State/UT_Tax"].hist()

# %%
sns.FacetGrid(df1, 
              hue="Place_of_Supply", 
              size=6) \
   .map(plt.hist, "Cess (₹)") \
   .add_legend();

# %%
with sns.plotting_context("notebook",font_scale=1.5):
    sns.set_style("whitegrid")
    sns.distplot(df1["Taxable_Value"],
                 kde=False,
                 color="tomato")
    sns.plt.title("Taxable_Value Distribution")
    plt.ylabel("Count");

# %% [markdown]
# # Clustering can be done on the data if we the proper gst data

# %%
X = df1.values
X = pd.DataFrame(X)

# %%
xx=x[['4', '9', '10', '11', '12', '13', '14']]

# %%
# Using the elbow method to find  the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Applying k-means to the cars dataset
kmeans = KMeans(n_clusters=3,init='k-means++',max_iter=300,n_init=10,random_state=0) 
y_kmeans = kmeans.fit_predict(X)

X = X.as_matrix(columns=None)

# %%
# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0,1],s=100,c='red',label='US')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1,1],s=100,c='blue',label='Japan')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2,1],s=100,c='green',label='Europe')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=300,c='yellow',label='Centroids')
plt.title('Clusters of car brands')
plt.legend()
plt.show()
